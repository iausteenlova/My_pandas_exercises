# %% [markdown]
# ## Pandas-Exercise 1
# #### Cars_data
# > python > pandas > dataFrame

# %%
import numpy as np
import pandas as pd

# %%
cd = pd.read_csv('https://pynative.com/wp-content/uploads/2019/01/Automobile_data.csv')

# %%
cd.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
cd.tail()
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 10 columns):
# index               61 non-null int64
# company             61 non-null object
# body-style          61 non-null object
# wheel-base          61 non-null float64
# length              61 non-null float64
# engine-type         61 non-null object
# num-of-cylinders    61 non-null object
# horsepower          61 non-null int64
# average-mileage     61 non-null int64
# price               58 non-null float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 4.8+ KB

# %%
#cd = cd.reset_index()

# %%
cd =cd.set_index('index')

# %%
cd.head(15)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# 5             audi        sedan        99.8   177.3         ohc
# 6             audi        wagon       105.8   192.7         ohc
# 9              bmw        sedan       101.2   176.8         ohc
# 10             bmw        sedan       101.2   176.8         ohc
# 11             bmw        sedan       101.2   176.8         ohc
# 13             bmw        sedan       103.5   189.0         ohc
# 14             bmw        sedan       103.5   193.8         ohc
# 15             bmw        sedan       110.0   197.0         ohc
# ...

# %%
cd.columns
# Out:
# Index(['company', 'body-style', 'wheel-base', 'length', 'engine-type',
#        'num-of-cylinders', 'horsepower', 'average-mileage', 'price'],
#       dtype='object')

# %%
cd = cd.drop_duplicates()

# %%
cd = cd.sort_values('horsepower',ascending=True)

# %%
cd =cd.dropna()

# %%
cd.reset_index('index',drop =True,inplace=True)

# %%
cd.to_csv('cardata.csv',index = False)

# %%
cardf = pd.read_csv('cardata.csv')

# %%
cardf.head(2)
# Out:
#           company body-style  wheel-base  length engine-type num-of-cylinders  \
# 53  mercedes-benz    hardtop       112.0   199.2        ohcv            eight
# 51            bmw      sedan       103.5   193.8         ohc              six
#
#     horsepower  average-mileage    price
# 53         184               14  45400.0
# 51         182               16  41315.0

# %%
cardf = cardf.sort_values('price',ascending = False)

# %%
cardf.iloc[0,0]
# Out:
# 'mercedes-benz'

# %%
toyota_cars = cardf.loc[cardf['company'].str.contains('toyota')]
#cardf.loc[cardf['company']=='toyota']
toyota_cars
# Out:
#    company body-style  wheel-base  length engine-type num-of-cylinders  \
# 47  toyota      wagon       104.5   187.8        dohc              six
# 7   toyota      wagon        95.7   169.7         ohc             four
# 9   toyota      wagon        95.7   169.7         ohc             four
# 5   toyota      wagon        95.7   169.7         ohc             four
# 6   toyota  hatchback        95.7   158.7         ohc             four
# 4   toyota  hatchback        95.7   158.7         ohc             four
# 8   toyota  hatchback        95.7   158.7         ohc             four
#
#     horsepower  average-mileage    price
# 47         156               19  15750.0
# 7           62               27   8778.0
# 9           62               27   7898.0
# 5           62               31   6918.0
# 6           62               31   6488.0
# 4           62               31   6338.0
# 8           62               35   5348.0

# %%
#tcpc = totalcarspercompany
tcpc = cardf.groupby(['company']).count()['length']
tcpc
# Out:
# company
# alfa-romero      3
# audi             4
# bmw              6
# chevrolet        3
# dodge            2
# honda            3
# isuzu            1
# jaguar           3
# mazda            5
# mercedes-benz    4
# mitsubishi       4
# nissan           5
# porsche          2
# toyota           7
# volkswagen       4
# volvo            2
# Name: length, dtype: int64

# %%
HP = toyota_cars.sort_values(['price'],ascending=False)
HP.iloc[0,:]
# Out:
# company             toyota
# body-style           wagon
# wheel-base           104.5
# length               187.8
# engine-type           dohc
# num-of-cylinders       six
# horsepower             156
# average-mileage         19
# price                15750
# Name: 47, dtype: object

# %%
volvo_cars = cardf.loc[cardf['company'].str.contains('volvo')]
#volvo_cars
HP = volvo_cars.sort_values(['price'],ascending=False)
HP.iloc[0,:]
# Out:
# company             volvo
# body-style          wagon
# wheel-base          104.3
# length              188.8
# engine-type           ohc
# num-of-cylinders     four
# horsepower            114
# average-mileage        23
# price               13415
# Name: 39, dtype: object

# %%
volkswagen_cars = cardf.loc[cardf['company'].str.contains('volkswagen')]
#volkswagen_cars
HP = volkswagen_cars.sort_values(['price'],ascending=False)
HP.iloc[0,:]
# Out:
# company             volkswagen
# body-style               sedan
# wheel-base                97.3
# length                   171.7
# engine-type                ohc
# num-of-cylinders          four
# horsepower                 100
# average-mileage             26
# price                     9995
# Name: 29, dtype: object

# %%
porsche_cars = cardf.loc[cardf['company'].str.contains('porsche')]
#porsche_cars
HP = porsche_cars.sort_values(['price'],ascending=False)
HP.iloc[0,:]
# Out:
#     company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 55  porsche  convertible        89.5   168.9        ohcf              six
# 56  porsche      hardtop        89.5   168.9        ohcf              six
#
#     horsepower  average-mileage    price
# 55         207               17  37028.0
# 56         207               17  34028.0
# company                 porsche
# body-style          convertible
# wheel-base                 89.5
# length                    168.9
# engine-type                ohcf
# num-of-cylinders            six
# horsepower                  207
# average-mileage              17
# price                     37028
# Name: 55, dtype: object

# %%
nissan_cars = cardf.loc[cardf['company'].str.contains('nissan')]
#nissan_cars
HP = nissan_cars.sort_values(['price'],ascending=False)
HP.iloc[0,:]
# Out:
# company             nissan
# body-style           sedan
# wheel-base           100.4
# length               184.6
# engine-type           ohcv
# num-of-cylinders       six
# horsepower             152
# average-mileage         19
# price                13499
# Name: 45, dtype: object

# %%
mitsubishi_cars = cardf.loc[cardf['company'].str.contains('mitsubishi')]
#mitsubishi_cars
HP = mitsubishi_cars.sort_values(['price'],ascending=False)
HP.iloc[0,:]
# Out:
# company             mitsubishi
# body-style               sedan
# wheel-base                96.3
# length                   172.4
# engine-type                ohc
# num-of-cylinders          four
# horsepower                  88
# average-mileage             25
# price                     8189
# Name: 26, dtype: object

# %%
#mercedes-benz
benz_cars = cardf.loc[cardf['company'].str.contains('mercedes-benz')]
#benz_cars
HP = benz_cars.sort_values(['price'],ascending=False)
HP.iloc[0,:]
# Out:
# company             mercedes-benz
# body-style                hardtop
# wheel-base                    112
# length                      199.2
# engine-type                  ohcv
# num-of-cylinders            eight
# horsepower                    184
# average-mileage                14
# price                       45400
# Name: 53, dtype: object

# %%
mazda_cars = cardf.loc[cardf['company'].str.contains('mazda')]
#mazda_cars
HP = mazda_cars.sort_values(['price'],ascending=False)
HP.iloc[0,:]
# Out:
# company             mazda
# body-style          sedan
# wheel-base          104.9
# length                175
# engine-type           ohc
# num-of-cylinders     four
# horsepower             72
# average-mileage        31
# price               18344
# Name: 22, dtype: object

# %%
#jaguar
jaguar_cars = cardf.loc[cardf['company'].str.contains('jaguar')]
#jaguar_cars
HP = jaguar_cars.sort_values(['price'],ascending=False)
HP.iloc[0,:]
# Out:
# company             jaguar
# body-style           sedan
# wheel-base             102
# length               191.7
# engine-type           ohcv
# num-of-cylinders    twelve
# horsepower             262
# average-mileage         13
# price                36000
# Name: 57, dtype: object

# %%
isuzu_cars = cardf.loc[cardf['company'].str.contains('isuzu')]
isuzu_cars
# Out:
#    company body-style  wheel-base  length engine-type num-of-cylinders  \
# 24   isuzu      sedan        94.3   170.7         ohc             four
#
#     horsepower  average-mileage   price
# 24          78               24  6785.0

# %%
honda_cars = cardf.loc[cardf['company'].str.contains('honda')]
#honda_cars
HP = honda_cars.sort_values(['price'],ascending=False)
HP.iloc[0,:]
# Out:
# company             honda
# body-style          sedan
# wheel-base           96.5
# length              175.4
# engine-type           ohc
# num-of-cylinders     four
# horsepower            101
# average-mileage        24
# price               12945
# Name: 33, dtype: object

# %%
dodge_cars = cardf.loc[cardf['company'].str.contains('dodge')]
#dodge_cars
HP = dodge_cars.sort_values(['price'],ascending=False)
HP.iloc[0,:]
# Out:
# company                 dodge
# body-style          hatchback
# wheel-base               93.7
# length                  157.3
# engine-type               ohc
# num-of-cylinders         four
# horsepower                 68
# average-mileage            31
# price                    6377
# Name: 14, dtype: object

# %%
chevrolet_cars = cardf.loc[cardf['company'].str.contains('chevrolet')]
#chevrolet_cars
HP = chevrolet_cars.sort_values(['price'],ascending=False)
HP.iloc[0,:]
# Out:
# company             chevrolet
# body-style              sedan
# wheel-base               94.5
# length                  158.8
# engine-type               ohc
# num-of-cylinders         four
# horsepower                 70
# average-mileage            38
# price                    6575
# Name: 20, dtype: object

# %%
bmw_cars = cardf.loc[cardf['company'].str.contains('bmw')]
#bmw_cars
HP = bmw_cars.sort_values(['price'],ascending=False)
HP.iloc[0,:]
# Out:
# company               bmw
# body-style          sedan
# wheel-base          103.5
# length              193.8
# engine-type           ohc
# num-of-cylinders      six
# horsepower            182
# average-mileage        16
# price               41315
# Name: 51, dtype: object

# %%
audi_cars = cardf.loc[cardf['company'].str.contains('audi')]
#audi_cars
HP = audi_cars.sort_values(['price'],ascending=False)
HP.iloc[0,:]
# Out:
# company              audi
# body-style          wagon
# wheel-base          105.8
# length              192.7
# engine-type           ohc
# num-of-cylinders     five
# horsepower            110
# average-mileage        19
# price               18920
# Name: 35, dtype: object

# %%
alfa_romero_cars = cardf.loc[cardf['company'].str.contains('alfa-romero')]
#alfa_romero_cars
HP = alfa_romero_cars.sort_values(['price'],ascending=False)
HP.iloc[0,:]
# Out:
# company             alfa-romero
# body-style          convertible
# wheel-base                 88.6
# length                    168.8
# engine-type                dohc
# num-of-cylinders           four
# horsepower                  111
# average-mileage              21
# price                     16500
# Name: 38, dtype: object

# %%
cardf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 53 to 0
# Data columns (total 9 columns):
# company             58 non-null object
# body-style          58 non-null object
# wheel-base          58 non-null float64
# length              58 non-null float64
# engine-type         58 non-null object
# num-of-cylinders    58 non-null object
# horsepower          58 non-null int64
# average-mileage     58 non-null int64
# price               58 non-null float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 7.0+ KB

# %%
#avg mileage of all cars w.r.t company
avg_mileage = cardf.groupby(['company']).mean()['average-mileage']
avg_mileage
# Out:
# company
# alfa-romero      20.333333
# audi             20.000000
# bmw              19.000000
# chevrolet        41.000000
# dodge            31.000000
# honda            26.333333
# isuzu            24.000000
# jaguar           14.333333
# mazda            28.000000
# mercedes-benz    18.000000
# mitsubishi       29.500000
# nissan           31.400000
# porsche          17.000000
# toyota           28.714286
# volkswagen       31.750000
# volvo            23.000000
# Name: average-mileage, dtype: float64

# %%
cardf.sort_values('price')
# Out:
#           company   body-style  wheel-base  length engine-type  \
# 0       chevrolet    hatchback        88.4   141.1           l
# 10          mazda    hatchback        93.1   159.1         ohc
# 8          toyota    hatchback        95.7   158.7         ohc
# 12     mitsubishi    hatchback        93.7   157.3         ohc
# 11          mazda    hatchback        93.1   159.1         ohc
# 16     mitsubishi    hatchback        93.7   157.3         ohc
# 15          dodge    hatchback        93.7   157.3         ohc
# 21      chevrolet    hatchback        94.5   155.9         ohc
# 4          toyota    hatchback        95.7   158.7         ohc
# 14          dodge    hatchback        93.7   157.3         ohc
# 6          toyota    hatchback        95.7   158.7         ohc
# 20      chevrolet        sedan        94.5   158.8         ohc
# 17         nissan        sedan        94.5   165.3         ohc
# 24          isuzu        sedan        94.3   170.7         ohc
# ...
